# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data1=pd.read_csv('dailyActivity_merged.csv')

# %%
data1
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    4/12/2016       13162       8.500000         8.500000
# 1    1503960366    4/13/2016       10735       6.970000         6.970000
# 2    1503960366    4/14/2016       10460       6.740000         6.740000
# 3    1503960366    4/15/2016        9762       6.280000         6.280000
# 4    1503960366    4/16/2016       12669       8.160000         8.160000
# ..          ...          ...         ...            ...              ...
# 935  8877689391     5/8/2016       10686       8.110000         8.110000
# 936  8877689391     5/9/2016       20226      18.250000        18.250000
# 937  8877689391    5/10/2016       10733       8.150000         8.150000
# 938  8877689391    5/11/2016       21420      19.559999        19.559999
# 939  8877689391    5/12/2016        8064       6.120000         6.120000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
#analysis of data
data1.describe()
# Out:
#                  Id    TotalSteps  TotalDistance  TrackerDistance  \
# count  9.400000e+02    940.000000     940.000000       940.000000
# mean   4.855407e+09   7637.910638       5.489702         5.475351
# std    2.424805e+09   5087.150742       3.924606         3.907276
# min    1.503960e+09      0.000000       0.000000         0.000000
# 25%    2.320127e+09   3789.750000       2.620000         2.620000
# 50%    4.445115e+09   7405.500000       5.245000         5.245000
# 75%    6.962181e+09  10727.000000       7.712500         7.710000
# max    8.877689e+09  36019.000000      28.030001        28.030001
#
#        LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# count                940.000000          940.000000                940.000000
# mean                   0.108171            1.502681                  0.567543
# std                    0.619897            2.658941                  0.883580
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        940 non-null    int64
#  1   ActivityDate              940 non-null    object
#  2   TotalSteps                940 non-null    int64
#  3   TotalDistance             940 non-null    float64
#  4   TrackerDistance           940 non-null    float64
#  5   LoggedActivitiesDistance  940 non-null    float64
#  6   VeryActiveDistance        940 non-null    float64
#  7   ModeratelyActiveDistance  940 non-null    float64
#  8   LightActiveDistance       940 non-null    float64
#  9   SedentaryActiveDistance   940 non-null    float64
#  10  VeryActiveMinutes         940 non-null    int64
#  11  FairlyActiveMinutes       940 non-null    int64
#  12  LightlyActiveMinutes      940 non-null    int64
# ...

# %%
data1.isnull().sum()
# Out:
# Id                          0
# ActivityDate                0
# TotalSteps                  0
# TotalDistance               0
# TrackerDistance             0
# LoggedActivitiesDistance    0
# VeryActiveDistance          0
# ModeratelyActiveDistance    0
# LightActiveDistance         0
# SedentaryActiveDistance     0
# VeryActiveMinutes           0
# FairlyActiveMinutes         0
# LightlyActiveMinutes        0
# SedentaryMinutes            0
# Calories                    0
# dtype: int64

# %%
#scatter plot of data
# sns.pairplot(data1,hue='Calories')

# %%
#merge two dataframes
data2=pd.read_csv('dailyCalories_merged.csv')
data2
# Out:
#              Id ActivityDay  Calories
# 0    1503960366   4/12/2016      1985
# 1    1503960366   4/13/2016      1797
# 2    1503960366   4/14/2016      1776
# 3    1503960366   4/15/2016      1745
# 4    1503960366   4/16/2016      1863
# ..          ...         ...       ...
# 935  8877689391    5/8/2016      2847
# 936  8877689391    5/9/2016      3710
# 937  8877689391   5/10/2016      2832
# 938  8877689391   5/11/2016      3832
# 939  8877689391   5/12/2016      1849
#
# [940 rows x 3 columns]

# %%
data3=pd.read_csv('heartrate_seconds_merged.csv')
data3
# Out:
#                  Id                  Time  Value
# 0        2022484408  4/12/2016 7:21:00 AM     97
# 1        2022484408  4/12/2016 7:21:05 AM    102
# 2        2022484408  4/12/2016 7:21:10 AM    105
# 3        2022484408  4/12/2016 7:21:20 AM    103
# 4        2022484408  4/12/2016 7:21:25 AM    101
# ...             ...                   ...    ...
# 2483653  8877689391  5/12/2016 2:43:53 PM     57
# 2483654  8877689391  5/12/2016 2:43:58 PM     56
# 2483655  8877689391  5/12/2016 2:44:03 PM     55
# 2483656  8877689391  5/12/2016 2:44:18 PM     55
# 2483657  8877689391  5/12/2016 2:44:28 PM     56
#
# [2483658 rows x 3 columns]

# %%
data1
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    4/12/2016       13162       8.500000         8.500000
# 1    1503960366    4/13/2016       10735       6.970000         6.970000
# 2    1503960366    4/14/2016       10460       6.740000         6.740000
# 3    1503960366    4/15/2016        9762       6.280000         6.280000
# 4    1503960366    4/16/2016       12669       8.160000         8.160000
# ..          ...          ...         ...            ...              ...
# 935  8877689391     5/8/2016       10686       8.110000         8.110000
# 936  8877689391     5/9/2016       20226      18.250000        18.250000
# 937  8877689391    5/10/2016       10733       8.150000         8.150000
# 938  8877689391    5/11/2016       21420      19.559999        19.559999
# 939  8877689391    5/12/2016        8064       6.120000         6.120000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
sns.barplot(x='Calories',y='TotalSteps',data=data1)
fig=plt.gcf()

# %%
data1.drop(labels=['ActivityDate','Id'],axis=1,inplace=True)

#regression analysis
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error


#split data into train and test
X=data1.drop(['Calories'],axis=1)  
y=data1['Calories']
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)


#create model
regressor=LinearRegression()
regressor.fit(X_train,y_train)


#predict
y_pred=regressor.predict(X_test)
y_pred
# Out:
# array([2040.43919128, 2096.78716616, 2392.48803018, 1861.45207903,
#        2250.4442247 , 4811.98500804, 2337.42570389, 2028.7593092 ,
#        2768.80334901, 3115.79894156, 2214.84644567, 5325.01197658,
#        2439.80836954, 2434.38417262, 2174.28808722, 2394.74541348,
#        1928.44266904, 2761.39943635, 1949.96741283, 2026.39605585,
#        1738.2328631 , 2036.81513351, 1705.76191276, 1798.08936151,
#        1735.2274714 , 2103.25956506, 2803.6734027 , 1681.85037144,
#        2225.91131162, 1722.59703776, 1740.6979453 , 1947.09327502,
#        3828.35997767, 2746.51026333, 1722.59703776, 2003.92183719,
#        2086.33621425, 2164.33488194, 2036.85053101, 3036.62736126,
#        2212.00025165, 2511.03545737, 3602.33773973, 1722.59703776,
#        2914.43079186, 2240.76062153, 2185.06877207, 2393.20619315,
#        2182.42549447, 2638.4457586 , 3316.16855443, 3616.17917854,
#        2246.88233292, 2250.38444094, 3015.24698691, 4195.9882418 ,
# ...

# %%
#heapmap of data
sns.heatmap(data1.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
regressor.coef_
# Out:
# array([-3.77239856e-01,  3.25652635e+02,  3.58688630e+02,  5.04476009e+01,
#        -3.15889038e+02, -3.52692957e+02, -1.31231254e+01, -1.67626241e+02,
#         1.83334150e+01,  1.23121996e+01,  1.00817651e-01,  3.27312766e-01])

# %%
#r2_score
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.7414195931173888

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-3a53dab9c8fc> in <module>
#       2 #import accuracy_score
#       3 from sklearn.metrics import accuracy_score
# ----> 4 accuracy_score(y_test,y_pred)
#       5
#
# d:\Users\YASWANTH\anaconda3\envs\gr\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# d:\Users\YASWANTH\anaconda3\envs\gr\lib\site-packages\sklearn\metrics\_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     200
#     201     # Compute accuracy for each possible representation
# --> 202     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
# ...

# %%
data4.drop(labels="Time",axis=1)
# Out:
#                   Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0         2022484408    4/12/2016       11875           8.34             8.34
# 1         2022484408    4/12/2016       11875           8.34             8.34
# 2         2022484408    4/12/2016       11875           8.34             8.34
# 3         2022484408    4/12/2016       11875           8.34             8.34
# 4         2022484408    4/12/2016       11875           8.34             8.34
# ...              ...          ...         ...            ...              ...
# 73205760  8877689391    5/12/2016        8064           6.12             6.12
# 73205761  8877689391    5/12/2016        8064           6.12             6.12
# 73205762  8877689391    5/12/2016        8064           6.12             6.12
# 73205763  8877689391    5/12/2016        8064           6.12             6.12
# 73205764  8877689391    5/12/2016        8064           6.12             6.12
#
# ...

# %%
# #visualize the data
# sns.pairplot(data4,hue='Calories')

# %%
# sns.barplot(x='Calories',y='TotalSteps',data=data4)

# %%
data4

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-643c6d77ca5f> in <module>
# ----> 1 data4.info()
#
# AttributeError: 'NoneType' object has no attribute 'info'
